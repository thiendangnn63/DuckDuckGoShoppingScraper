# %%
import pandas as pd

file = pd.read_csv('ITEMS_phase1.csv')
file
# Out:
#                                            ProductName  Price  ReviewCount  \
# 0             Absopure Bottled Water 16.9 Fl. Oz. 1 Pk   6.99          NaN
# 1      KS Purified Drinking Water, 16.9 Oz. 14 Bottles  15.97          6.0
# 2    Aquafina Purified Bottled Drinking Water, 16.9...   6.98      11000.0
# 3    Essentia Water, Ionized Alkaline 6 Count, 202....   9.48       1500.0
# 4    Pure Life 571863 Nestle Pure Life Water 16.9 O...   9.99        857.0
# ..                                                 ...    ...          ...
# 119      San Benedetto Natural Water, 8.45 Fluid Ounce   6.99          NaN
# 120  Sparkling Water Bottles 12-Pack Carbonated Spr...  19.93          NaN
# 121  Poland Spring 100% Natural Spring Water, 8 Oun...  17.67          NaN
# 122        Nestle Waters Nestle Pure Life Water, 24 Ea  15.78          NaN
# 123  2-Pack Boxed Water Purified Drinking Water 16....  12.50          NaN
#
# ...

# %%
import numpy as np
# check for nan
nan_brands = file[file['Brand'].isna()]
nan_brands
# Out:
# Empty DataFrame
# Columns: [ProductName, Price, ReviewCount, Brand, URL]
# Index: []

# %%
file['Brand'].value_counts()
# Out:
# Brand
# Walmart                    52
# Amazon.com                 38
# eBay.com                    8
# eBay                        8
# Ace Hardware                2
# Safeway                     2
# Vitacost                    2
# medical products supply     1
# AlmaGourmet                 1
# Faire                       1
# Kroger                      1
# Fred Meyer                  1
# Smith's                     1
# Fry's                       1
# Office Depot                1
# MyBestShoe                  1
# Qietaw                      1
# Max Warehouse               1
# Colavita Store              1
# Name: count, dtype: int64
